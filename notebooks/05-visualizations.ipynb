# %% [markdown]
# Before starting to build our model, let's create some visualizations of our variables to see any underlying trends. This will highlight important variables for determining the winner of a match. It can also be later to cross reference with the trained model to ensure the most important features are listed.
